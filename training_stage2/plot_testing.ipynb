# %%
import matplotlib.pyplot as plt

# Validation loss extracted from training log
validation_loss_values = [
    2.7374, 2.6893, 2.6775, 2.6484, 2.6208, 2.6059, 2.6119, 2.6056, 2.6198, 3.1733,
    2.7105, 2.6987, 2.6850, 2.6789, 2.6789, 2.6789, 2.6789, 2.6789, 2.6789, 2.6789,
    2.6789, 2.6789, 2.6789, 2.6789, 2.6610, 2.6535, 2.6473, 2.6349, 2.6452, 2.6507,
    2.6481, 2.6402, 2.6323, 2.6245, 2.6176, 2.6059, 2.6007, 2.5984, 2.5880, 2.6150,
    2.5793, 2.5632, 2.5550, 2.5320, 2.5360, 2.6265, 2.5501, 2.5536, 2.4461, 2.4422,
    2.4417, 2.4536, 2.4401, 2.4393, 2.4350, 2.4290, 2.4290, 2.4290, 2.4290, 2.4290,
    2.4290, 2.4290, 2.4290, 2.4290, 2.4290, 2.4330, 2.4140, 2.4129, 2.4534, 2.4109,
    2.4089, 2.4988, 2.3202, 2.3834, 2.3856, 2.3805, 2.3798, 2.3768, 2.3776, 2.3879,
    2.3750, 2.3755, 2.3630, 2.3779, 2.3622, 2.3556, 2.3495, 2.3447, 2.3459, 2.3334,
    2.3302, 2.3238, 2.3359, 2.3196, 2.3186, 2.3179, 2.3167, 2.3163, 2.3157, 2.3154,
]

# Plotting the validation loss values
plt.figure(figsize=(10, 6))
plt.plot(range(1, 101), validation_loss_values, marker='o', color='b')
plt.title('Validation Loss Across 100 Epochs')
plt.xlabel('Epoch')
plt.ylabel('Validation Loss')
plt.grid(True)
plt.show()
